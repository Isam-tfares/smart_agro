# %%
import pandas as pd

# %%
df=pd.read_csv('SolarPrediction.csv')
df
# Out:
#          UNIXTime                   Data      Time  Radiation  Temperature  \
# 0      1475229326  9/29/2016 12:00:00 AM  23:55:26       1.21           48
# 1      1475229023  9/29/2016 12:00:00 AM  23:50:23       1.21           48
# 2      1475228726  9/29/2016 12:00:00 AM  23:45:26       1.23           48
# 3      1475228421  9/29/2016 12:00:00 AM  23:40:21       1.21           48
# 4      1475228124  9/29/2016 12:00:00 AM  23:35:24       1.17           48
# ...           ...                    ...       ...        ...          ...
# 32681  1480587604  12/1/2016 12:00:00 AM  00:20:04       1.22           44
# 32682  1480587301  12/1/2016 12:00:00 AM  00:15:01       1.17           44
# 32683  1480587001  12/1/2016 12:00:00 AM  00:10:01       1.20           44
# 32684  1480586702  12/1/2016 12:00:00 AM  00:05:02       1.23           44
# 32685  1480586402  12/1/2016 12:00:00 AM  00:00:02       1.20           44
#
# ...

# %%
df['Hour']=df.Time.apply(lambda x: x.split(':')[0])
df
# Out:
#          UNIXTime                   Data      Time  Radiation  Temperature  \
# 0      1475229326  9/29/2016 12:00:00 AM  23:55:26       1.21           48
# 1      1475229023  9/29/2016 12:00:00 AM  23:50:23       1.21           48
# 2      1475228726  9/29/2016 12:00:00 AM  23:45:26       1.23           48
# 3      1475228421  9/29/2016 12:00:00 AM  23:40:21       1.21           48
# 4      1475228124  9/29/2016 12:00:00 AM  23:35:24       1.17           48
# ...           ...                    ...       ...        ...          ...
# 32681  1480587604  12/1/2016 12:00:00 AM  00:20:04       1.22           44
# 32682  1480587301  12/1/2016 12:00:00 AM  00:15:01       1.17           44
# 32683  1480587001  12/1/2016 12:00:00 AM  00:10:01       1.20           44
# 32684  1480586702  12/1/2016 12:00:00 AM  00:05:02       1.23           44
# 32685  1480586402  12/1/2016 12:00:00 AM  00:00:02       1.20           44
#
# ...

# %%
df['timestamp']=df.Data.apply(lambda x: x.split(' ')[0])+" "+df.Hour
df
# Out:
#          UNIXTime                   Data      Time  Radiation  Temperature  \
# 0      1475229326  9/29/2016 12:00:00 AM  23:55:26       1.21           48
# 1      1475229023  9/29/2016 12:00:00 AM  23:50:23       1.21           48
# 2      1475228726  9/29/2016 12:00:00 AM  23:45:26       1.23           48
# 3      1475228421  9/29/2016 12:00:00 AM  23:40:21       1.21           48
# 4      1475228124  9/29/2016 12:00:00 AM  23:35:24       1.17           48
# ...           ...                    ...       ...        ...          ...
# 32681  1480587604  12/1/2016 12:00:00 AM  00:20:04       1.22           44
# 32682  1480587301  12/1/2016 12:00:00 AM  00:15:01       1.17           44
# 32683  1480587001  12/1/2016 12:00:00 AM  00:10:01       1.20           44
# 32684  1480586702  12/1/2016 12:00:00 AM  00:05:02       1.23           44
# 32685  1480586402  12/1/2016 12:00:00 AM  00:00:02       1.20           44
#
# ...

# %%
# To keep the last occurrence of duplicates
df_unique = df.drop_duplicates(subset=['timestamp'], keep='first')
df_unique
# Out:
#          UNIXTime                   Data      Time  Radiation  Temperature  \
# 0      1475229326  9/29/2016 12:00:00 AM  23:55:26       1.21           48
# 12     1475225720  9/29/2016 12:00:00 AM  22:55:20       1.22           49
# 24     1475222120  9/29/2016 12:00:00 AM  21:55:20       1.22           50
# 36     1475218518  9/29/2016 12:00:00 AM  20:55:18       1.19           50
# 48     1475214923  9/29/2016 12:00:00 AM  19:55:23       1.22           50
# ...           ...                    ...       ...        ...          ...
# 32626  1480604102  12/1/2016 12:00:00 AM  04:55:02       1.19           42
# 32638  1480600505  12/1/2016 12:00:00 AM  03:55:05       1.20           43
# 32650  1480596904  12/1/2016 12:00:00 AM  02:55:04       1.22           41
# 32662  1480593302  12/1/2016 12:00:00 AM  01:55:02       1.20           43
# 32674  1480589701  12/1/2016 12:00:00 AM  00:55:01       1.21           43
#
# ...

# %%
myDf=pd.read_json("./water_level_data_with_start_time.json")
myDf
# Out:
#               timestamp  water_level
# 0   2024-05-01 00:00:00        14.80
# 1   2024-05-01 01:00:00        31.72
# 2   2024-05-01 02:00:00         5.57
# 3   2024-05-01 03:00:00         3.57
# 4   2024-05-01 04:00:00        48.47
# ..                  ...          ...
# 715 2024-05-30 19:00:00        76.07
# 716 2024-05-30 20:00:00         1.27
# 717 2024-05-30 21:00:00        87.30
# 718 2024-05-30 22:00:00        30.37
# 719 2024-05-30 23:00:00        32.71
#
# [720 rows x 2 columns]

# %%
myDf['Temperature']=df_unique.Temperature.values[:len(myDf)]
myDf['Pressure']=df_unique.Pressure.values[:len(myDf)]
myDf['Humidity']=df_unique.Humidity.values[:len(myDf)]
myDf['Speed']=df_unique.Speed.values[:len(myDf)]
myDf
# Out:
#               timestamp  water_level  Temperature  Pressure  Humidity  Speed
# 0   2024-05-01 00:00:00        14.80           48     30.46        59   5.62
# 1   2024-05-01 01:00:00        31.72           49     30.47        99   6.75
# 2   2024-05-01 02:00:00         5.57           50     30.47        96   5.62
# 3   2024-05-01 03:00:00         3.57           50     30.47        91   7.87
# 4   2024-05-01 04:00:00        48.47           50     30.46        47   6.75
# ..                  ...          ...          ...       ...       ...    ...
# 715 2024-05-30 19:00:00        76.07           50     30.40       102   5.62
# 716 2024-05-30 20:00:00         1.27           51     30.39       102  13.50
# 717 2024-05-30 21:00:00        87.30           51     30.40       102   4.50
# 718 2024-05-30 22:00:00        30.37           50     30.41       102   7.87
# 719 2024-05-30 23:00:00        32.71           51     30.42       101  12.37
#
# [720 rows x 6 columns]

# %%
myDf['timestamp'] = myDf['timestamp'].astype(str)
json_file_path = 'data.json'
myDf.to_json(json_file_path, orient='records')

# %%
# from flask import Flask, jsonify, request
# from flask_cors import CORS
from pymongo import MongoClient
from datetime import datetime,timedelta

# app = Flask(__name__)
# CORS(app)

# MongoDB connection
uri = "mongodb+srv://tfaresisam:zx6kbazwauPRrAbz@cluster0.abvx5ep.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

client = MongoClient(uri)
db = client.SmartArgo
collection = db.data

# %%
data = list(collection.find({}, {'_id': 0}))  # Exclude the '_id' field
data
# Out:
# [{'timestamp': '2024-05-01 00:00:00',
#   'water_level': 14.8,
#   'Temperature': 48,
#   'Pressure': 30.46,
#   'Humidity': 59,
#   'Speed': 5.62},
#  {'timestamp': '2024-05-01 01:00:00',
#   'water_level': 31.72,
#   'Temperature': 49,
#   'Pressure': 30.47,
#   'Humidity': 99,
#   'Speed': 6.75},
#  {'timestamp': '2024-05-01 02:00:00',
#   'water_level': 5.57,
#   'Temperature': 50,
#   'Pressure': 30.47,
#   'Humidity': 96,
#   'Speed': 5.62},
#  {'timestamp': '2024-05-01 03:00:00',
#   'water_level': 3.57,
#   'Temperature': 50,
#   'Pressure': 30.47,
#   'Humidity': 91,
#   'Speed': 7.87},
#  {'timestamp': '2024-05-01 04:00:00',
#   'water_level': 48.47,
#   'Temperature': 50,
#   'Pressure': 30.46,
#   'Humidity': 47,
#   'Speed': 6.75},
#  {'timestamp': '2024-05-01 05:00:00',
#   'water_level': 21.56,
#   'Temperature': 51,
#   'Pressure': 30.45,
#   'Humidity': 51,
#   'Speed': 6.75},
#  {'timestamp': '2024-05-01 06:00:00',
#   'water_level': 69.91,
#   'Temperature': 55,
# ...

# %%
from datetime import datetime

def get_data_of_month_year(data, month, year,column):
    filtered_data = []
    for entry in data:
        timestamp = datetime.strptime(entry['timestamp'], '%Y-%m-%d %H:%M:%S')
        if timestamp.month == month and timestamp.year == year:
            if column=="all":
                filtered_data.append(entry)
            else:
                filtered_data.append({'timestamp':entry['timestamp'],column:entry[column]})
    return filtered_data

get_data_of_month_year(data,5,2024,'Speed')
# Out:
# [{'timestamp': '2024-05-01 00:00:00', 'Speed': 5.62},
#  {'timestamp': '2024-05-01 01:00:00', 'Speed': 6.75},
#  {'timestamp': '2024-05-01 02:00:00', 'Speed': 5.62},
#  {'timestamp': '2024-05-01 03:00:00', 'Speed': 7.87},
#  {'timestamp': '2024-05-01 04:00:00', 'Speed': 6.75},
#  {'timestamp': '2024-05-01 05:00:00', 'Speed': 6.75},
#  {'timestamp': '2024-05-01 06:00:00', 'Speed': 4.5},
#  {'timestamp': '2024-05-01 07:00:00', 'Speed': 3.37},
#  {'timestamp': '2024-05-01 08:00:00', 'Speed': 3.37},
#  {'timestamp': '2024-05-01 09:00:00', 'Speed': 4.5},
#  {'timestamp': '2024-05-01 10:00:00', 'Speed': 7.87},
#  {'timestamp': '2024-05-01 11:00:00', 'Speed': 9},
#  {'timestamp': '2024-05-01 12:00:00', 'Speed': 4.5},
#  {'timestamp': '2024-05-01 13:00:00', 'Speed': 5.62},
#  {'timestamp': '2024-05-01 14:00:00', 'Speed': 9},
#  {'timestamp': '2024-05-01 15:00:00', 'Speed': 2.25},
#  {'timestamp': '2024-05-01 16:00:00', 'Speed': 5.62},
#  {'timestamp': '2024-05-01 17:00:00', 'Speed': 7.87},
# ...

# %%
from datetime import datetime

def get_data_of_day_month_year(data, day, month, year):
    filtered_data = []
    for entry in data:
        timestamp = datetime.strptime(entry['timestamp'], '%Y-%m-%d %H:%M:%S')
        if timestamp.day == day and timestamp.month == month and timestamp.year == year:
            filtered_data.append(entry)
    return filtered_data

get_data_of_day_month_year(data,3,5,2024)
# Out:
# [{'timestamp': '2024-05-03 00:00:00',
#   'water_level': 26.63,
#   'Temperature': 49,
#   'Pressure': 30.4,
#   'Humidity': 89,
#   'Speed': 4.5},
#  {'timestamp': '2024-05-03 01:00:00',
#   'water_level': 55.7,
#   'Temperature': 50,
#   'Pressure': 30.41,
#   'Humidity': 88,
#   'Speed': 4.5},
#  {'timestamp': '2024-05-03 02:00:00',
#   'water_level': 58.71,
#   'Temperature': 50,
#   'Pressure': 30.41,
#   'Humidity': 91,
#   'Speed': 5.62},
#  {'timestamp': '2024-05-03 03:00:00',
#   'water_level': 91.15,
#   'Temperature': 51,
#   'Pressure': 30.41,
#   'Humidity': 94,
#   'Speed': 2.25},
#  {'timestamp': '2024-05-03 04:00:00',
#   'water_level': 87.58,
#   'Temperature': 52,
#   'Pressure': 30.4,
#   'Humidity': 96,
#   'Speed': 1.12},
#  {'timestamp': '2024-05-03 05:00:00',
#   'water_level': 37.04,
#   'Temperature': 53,
#   'Pressure': 30.39,
#   'Humidity': 94,
#   'Speed': 4.5},
#  {'timestamp': '2024-05-03 06:00:00',
#   'water_level': 77.04,
#   'Temperature': 56,
# ...
